# %% [markdown]
# <a href="https://colab.research.google.com/github/LilianeEff/Data201/blob/main/classwork2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_1=pd.read_csv('/content/classwork_2 (1).csv')
df_1.head()
# Out:
#         Y  X1    X2  X3    X4    X5  X6
# 0  208500   7  1710   2   856  65.0  WD
# 1  181500   6  1262   2  1262  80.0  WD
# 2  223500   7  1786   2   920  68.0  WD
# 3  140000   7  1717   3   756  60.0  WD
# 4  250000   8  2198   3  1145  84.0  WD

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Y       1460 non-null   int64
#  1   X1      1460 non-null   int64
#  2   X2      1460 non-null   int64
#  3   X3      1460 non-null   int64
#  4   X4      1460 non-null   int64
#  5   X5      1201 non-null   float64
#  6   X6      1460 non-null   object
# dtypes: float64(1), int64(5), object(1)
# memory usage: 80.0+ KB

# %%
df_1.dtypes
# Out:
# Y       int64
# X1      int64
# X2      int64
# X3      int64
# X4      int64
# X5    float64
# X6     object
# dtype: object

# %%
df_1.describe()
# Out:
#                    Y           X1           X2           X3           X4  \
# count    1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   180921.195890     6.099315  1515.463699     1.767123  1057.429452
# std     79442.502883     1.382997   525.480383     0.747315   438.705324
# min     34900.000000     1.000000   334.000000     0.000000     0.000000
# 25%    129975.000000     5.000000  1129.500000     1.000000   795.750000
# 50%    163000.000000     6.000000  1464.000000     2.000000   991.500000
# 75%    214000.000000     7.000000  1776.750000     2.000000  1298.250000
# max    755000.000000    10.000000  5642.000000     4.000000  6110.000000
#
#                 X5
# count  1201.000000
# mean     70.049958
# std      24.284752
# min      21.000000
# 25%      59.000000
# 50%      69.000000
# 75%      80.000000
# max     313.000000

# %%
df_1.groupby('X6')['Y'].mean()
# Out:
# X6
# COD      143973.255814
# CWD      210600.000000
# Con      269600.000000
# ConLD    138780.888889
# ConLI    200390.000000
# ConLw    143700.000000
# New      274945.418033
# Oth      119850.000000
# WD       173401.836622
# Name: Y, dtype: float64

# %%
df_1.isnull().count()
# Out:
# Y     1460
# X1    1460
# X2    1460
# X3    1460
# X4    1460
# X5    1460
# X6    1460
# dtype: int64

# %%
df_3= df_1.fillna(df_1.mean())
print(df_3.isnull().sum())
# Out:
# Y        0
# X1       0
# X2       0
# X3       0
# X4       0
# X5       0
# X6    1460
# dtype: int64

# %%
print(df_3)
# Out:
#            Y  X1    X2  X3    X4    X5  X6
# 0     208500   7  1710   2   856  65.0 NaN
# 1     181500   6  1262   2  1262  80.0 NaN
# 2     223500   7  1786   2   920  68.0 NaN
# 3     140000   7  1717   3   756  60.0 NaN
# 4     250000   8  2198   3  1145  84.0 NaN
# ...      ...  ..   ...  ..   ...   ...  ..
# 1455  175000   6  1647   2   953  62.0 NaN
# 1456  210000   6  2073   2  1542  85.0 NaN
# 1457  266500   7  2340   1  1152  66.0 NaN
# 1458  142125   5  1078   1  1078  68.0 NaN
# 1459  147500   5  1256   1  1256  75.0 NaN
#
# [1460 rows x 7 columns]

# %%
df_2= pd.get_dummies(df_1, columns=['X6'])
df_2.head()
# Out:
#         Y  X1    X2  X3    X4    X5
# 0  208500   7  1710   2   856  65.0
# 1  181500   6  1262   2  1262  80.0
# 2  223500   7  1786   2   920  68.0
# 3  140000   7  1717   3   756  60.0
# 4  250000   8  2198   3  1145  84.0

# %%
sns.boxplot(x='X1', y='Y', data=df_1)
plt.show()

# %%
sns.scatterplot(x='X1', y='Y', data=df_1)
plt.show()
